# %% [markdown]
# ## My lesson 2

# %%
from random import randint
import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt

from plot_helper import *

# %%
A = np.array([[1,1], [-1,1]])

# %%
plot_linear_transformation(A)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
i = np.array([1,0])
j = np.array([0,1])

# %%
a = np.array([1,-1])
b = np.array([1,1])

# %%
vectors = [i,a]
plot_vector(vectors)
# Out:
# <img src="data:image/png;base64,..." width="300">

# %%
np.linalg.norm(i)
# Out:
# 1.0

# %%
np.linalg.norm(a)
# Out:
# 1.4142135623730951

# %%
plot_linear_transformation(A)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
A_inv = np.linalg.inv(A)
plot_linear_transformation(A_inv)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
plot_linear_transformations(A, A_inv)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
B = np.array([[1,1], [0,-1]])

# %%
plot_linear_transformation(B)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
B_inv = np.linalg.inv(B)

# %%
plot_linear_transformations(B, B_inv)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
plot_linear_transformation(B_inv)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
C = np.array( [[2,1], [1,2]])
print(C)
# Out:
# [[2 1]
#  [1 2]]

# %%
plot_linear_transformation(C)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
alpha = np.linspace(0, 2*np.pi, 41)

# %%
vectors = list(zip(np.cos(alpha), np.sin(alpha)))

# %%
plot_vector(vectors)
# Out:
# <img src="data:image/png;base64,..." width="300">

# %%
vectors[0]
# Out:
# (1.0, 0.0)

# %%
C.dot(vectors[0])
# Out:
# array([2., 1.])

# %%
newvectors = []

for i in range(len(vectors)):
    newvectors.append(C.dot(vectors[i]))

# %%
plot_vector(newvectors)
# Out:
# <img src="data:image/png;base64,..." width="300">

# %%
lengths = []
for i in range(len(newvectors)):
    lengths.append(np.linalg.norm(newvectors[i]))

# %%
semi_major = max(lengths)
print(semi_major)
# Out:
# 3.0000000000000004

# %%
semi_minor = min(lengths)
print(semi_minor)
# Out:
# 1.0

# %%
s = semi_major/np.sqrt(2)

# %%
u1 = np.array([s, s])
print(u1)
# Out:
# [2.12132034 2.12132034]

# %%
C_inv = np.linalg.inv(C)
v1 = C_inv.dot(u1)

# %%
plot_vector([u1, v1])
# Out:
# <img src="data:image/png;base64,..." width="300">

# %% [markdown]
# The vector that landed on the semi-major axis was only scaled by the effect of $C$
#
# $$ C \mathbf{v}_1 = s1 \mathbf{v}_1 $$

# %%
u2 = np.array([semi_minor/np.sqrt(2), -semi_minor/np.sqrt(2)])
print(u2)
# Out:
# [ 0.70710678 -0.70710678]

# %%
v2 = C_inv.dot(u2)
print(v2)
# Out:
# [ 0.70710678 -0.70710678]

# %%
plot_vector([u2, v2])
# Out:
# <img src="data:image/png;base64,..." width="300">

# %%
np.linalg.norm(u2)
# Out:
# 0.9999999999999999

# %% [markdown]
# ---
#
# ## System of equations

# %%
A
# Out:
# array([[ 1,  1],
#        [-1,  1]])

# %%
c = np.array([1,5])
x = A_inv.dot(c)
print(x)
# Out:
# [-2.  3.]

# %% [markdown]
# Row by row , the system represents two lines:
#
# $$ y = 1-x$$
# $$ y = 5+x$$

# %%
xvalues = np.linspace(-4,2)
m1, b1, m2, b2 = -1, 1, 1, 5
pyplot.figure(figsize=(2,2))
pyplot.plot(xvalues, m2*xvalues+b2)
pyplot.plot(xvalues, m1*xvalues+b1)
pyplot.scatter(x[0], x[1])
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
D = np.array([[-2,-1], [1,0.5]])
print(D)
# Out:
# [[-2.  -1. ]
#  [ 1.   0.5]]

# %%
plot_linear_transformation(D)
# Out:
# <div id='8a6a6306-ab62-41c1-a694-c3a58cae32e8'></div>
